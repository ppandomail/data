# %% [markdown]
# # Regresión Lineal Simple

# %% [markdown]
# * Estudiar si existe un comportamiento lineal entre dos variables
# numéricas
# * Ver si una de las variables (a la que llamaremos variable independiente) nos ayuda a predecir o explicar el comportamiento de otra variable (que llamaremos dependiente)
# * Ejemplo: Estudiar cómo cambia el peso de una persona de acuerdo a su edad
# * ¿Podemos afirmar, con un cierto nivel de significación, que existe evidencia de que el peso de una persona tiende a aumentar con la edad?
# * ¿Podemos predecir, aproximadamente, la cantidad de grasa en sangre según la edad de la persona? ¿Qué grado de confianza tiene esa predicción?

# %% [markdown]
# * Objetivo: Encontrar la recta que mejor ajusta a los datos
# * Hay que definir un criterio para elegir la recta que mejor ajusta a los datos --> y = β0 + β1x
# * Predicho: punto sobre la recta --> (x, ŷ)
# * Residuo: distancia entre el punto y la recta --> r = y - ŷ

# %% [markdown]
# * Encontrar los parámetros β0 y β1
#     * Matemáticos: Método de Mínimos Cuadrados (MC)
#     * Estadístico: Modelo de Regresión Lineal (MRL)

# %% [markdown]
# * Covarianza entre dos VA --> Cov(X, Y) = E[(X − E(X))(Y − E(Y))]
#     *  Cov(X, Y) > 0: ambas variables tienden a aumentar juntas (relación positiva)
#     *  Cov(X, Y) < 0: cuando una variable aumenta, la otra tiende a disminuir (relación negativa)
#     *  Cov(X, Y) ≈ 0: no hay relación lineal clara

# %% [markdown]
# * Coeficiente de correlación lineal: ρxy = Cov(X, Y) / (sqrt(Var(X)) * sqrt(Var(Y)))
# * Toma valores entre [-1, 1]

# %% [markdown]
# ## Modelo de regresión lineal simple

# %% [markdown]
# * Estudia la relación entre dos variables aleatorias:
#     * X = variable predictora, regresora o explicativa
#     * Y = variable dependiente o respuesta

# %% [markdown]
# * Permita:
#     * Analizar si existe una relación lineal entre ambas variables
#     * Cuantificar esta relación mediante un estudio del modelo
#     * Predecir el valor de Y para un valor dado de X = x

# %% [markdown]
# * Forma: Yi = β0 + β1Xi + εi
#   * β0: ordenada al origen o intercept, indica el valor medio de Y cuando X = 0
#   * β1: pendiente, indica la variación media de la variable respuesta cuando X varía en una unidad
#   * εi: errores --> εi ∼ N(0, σ^2)
# * Se desconocen los parámetros: β0, β1 y σ. Hay que estimarlos
# * Método de Máxima Verosimilitud (MV) para estimar los parámetros: ^β0 MV, ^β1 MV y ^σ^2MV
# * Encontrar el valor del parámetro que maximiza la función de verosimilitud, es decir, la probabilidad (o densidad) de observar los datos muestrales, dados esos parámetros

# %% [markdown]
# ### Ejemplo

# %%
library(ggplot2)
library(GGally)

# %%
setwd("/Users/ppando/Materias/data/materias/aprendizaje-automatico/bd")

# %%
# Lectura del archivo
grasas <- read.csv("Grasas.csv", sep = ";")

# %%
# Visualización de variables
names(grasas)
# Out:
# [1] "peso"   "edad"   "grasas"

# %%
# Visualización de la estructura del archivo
str(grasas)
# Out:
# 'data.frame':	25 obs. of  3 variables:
#  $ peso  : int  84 73 65 70 76 69 63 72 79 75 ...
#  $ edad  : int  46 20 52 30 57 25 28 36 57 44 ...
#  $ grasas: int  354 190 405 263 451 302 288 385 402 365 ...

# %%
head(grasas)
# Out:
#   peso edad grasas
# 1 84   46   354
# 2 73   20   190
# 3 65   52   405
# 4 70   30   263
# 5 76   57   451
# 6 69   25   302

# %%
# Gráfico de dispersión (para explorar cómo se relacionan las variables entre sí)
ggpairs(grasas,
        columns = 1:3,
        mapping = aes(alpha = 0.9),
        upper = list(continuous = wrap("points", color = "darkred")),
        lower = list(continuous = wrap("points", color = "blue")),
        diag = list(continuous = wrap("densityDiag", fill = "lightblue")))
# Out:
# plot without title

# %% [markdown]
# El gráfico sugiere la presencia de una relación lineal entre las variables edad y grasas. En cambio, no se observa una asociación evidente entre los otros pares de variables.

# %%
# scatter plot
ggplot(data=grasas, aes(x=edad, y=grasas)) + geom_point(size=2)
# Out:
# plot without title

# %% [markdown]
# ### Planteo del modelo de regresión lineal

# %%
regresion <- lm(grasas ~ edad, data = grasas)
regresion
# Out:
# Call:
# lm(formula = grasas ~ edad, data = grasas)
#
# Coefficients:
# (Intercept)         edad
#     102.575        5.321

# %%
summary(regresion)
# Out:
# Call:
# lm(formula = grasas ~ edad, data = grasas)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -63.478 -26.816  -3.854  28.315  90.881
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 102.5751    29.6376   3.461  0.00212 **
# edad          5.3207     0.7243   7.346 1.79e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 43.46 on 23 degrees of freedom
# Multiple R-squared:  0.7012,	Adjusted R-squared:  0.6882
# F-statistic: 53.96 on 1 and 23 DF,  p-value: 1.794e-07

# %%
names(regresion)
# Out:
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"

# %% [markdown]
# ### Extracción de los coeficientes del modelo

# %%
regresion$coefficients
# Out:
# (Intercept)        edad
#  102.575142    5.320676

# %%
b0 <- round(regresion$coefficients[1],2)
b0
# Out:
# (Intercept)
#      102.58

# %%
b1 <- round(regresion$coefficients[2],2)
b1
# Out:
# edad
# 5.32

# %% [markdown]
# ### Interpretación de los parámetros del modelo

# %% [markdown]
# * **^β0** = 102.5751, representa la cantidad estimada de grasas en sangre cuando la edad es igual a cero
# * **^β1** = 5.3207, indica que, en promedio, un incremento de una unidad en la edad se asocia con un aumento del 5.321 unidades en la cantidad de grasas en sangre

# %% [markdown]
# * La ecuación de la recta que mejor se ajusta a este conjunto de datos es:
#     * **y = 102.57 + 5.321x**

# %% [markdown]
# ### Gráfico de dispersión y recta de regresión ajustada

# %%
ggplot(grasas, aes(x=edad, y=grasas)) + 
  geom_point() +
  geom_smooth(method='lm', formula=y~x, se=FALSE, col='dodgerblue1') +
  theme_light()
# Out:
# plot without title

# %% [markdown]
# ### Valores predichos

# %%
regresion$fitted.values
# Out:
#        1        2        3        4        5        6        7        8
# 347.3263 208.9887 379.2503 262.1954 405.8537 235.5921 251.5541 294.1195
#        9       10       11       12       13       14       15       16
# 405.8537 336.6849 230.2714 267.5161 379.2503 224.9507 421.8157 357.9676
#       17       18       19       20       21       22       23       24
# 283.4781 373.9296 368.6090 283.4781 347.3263 224.9507 299.4402 315.4022
#       25
# 262.1954

# %% [markdown]
# ### Residuos

# %%
regresion$residuals
# Out:
#            1            2            3            4            5            6
#   6.67374689 -18.98866868  25.74968894   0.80456808  45.14630732  66.40794970
#            7            8            9           10           11           12
#  36.44592073  90.88051013  -3.85369268  28.31509954 -21.27137398  22.48389175
#           13           14           15           16           17           18
# -33.25031106  29.04930235 -26.81572165  76.03239424 -63.47813722   0.07036527
#           19           20           21           22           23           24
# -60.60895841 -63.47813722 -36.32625311 -43.95069765 -25.44016619 -12.40219517
#           25
# -18.19543192

# %% [markdown]
# ## Diagnóstico de la regresión

# %% [markdown]
# * Son técnicas que permiten validar el cumplimiento de los supuestos del modelo planteado
# * Se basan en el análisis de los residuos
# * Los residuos son observables ri = Yi − ^Yi
# * Los residuos no son independientes, están correlacionados
# * Gráficos de residuos (ri) vs la covariable (Xi)
# * ¿Cómo debería verse el gráfico de residuos vs. la covariable (o los predichos) si el modelo es adecuado?
# * Si el modelo es correcto, el gráfico debería lucir como una nube de puntos sin estructura, ubicada alrededor del eje horizontal

# %%
# Grafico residuos estandarizados vs predichos
res.pred.df <- data.frame(x=regresion$fitted.values, y=rstandard(regresion))
ggplot(data=res.pred.df, aes(x,y)) +
  geom_point(size=1) +
  geom_hline(yintercept = 0, color="red") +
  theme_minimal() +
  labs(title = "Residuos estandarizados vs. predichos",
       x = "valores predichos",
       y = "residuos estandarizados")
# Out:
# plot without title

# %%
# qqplot residuos estandarizados (testeo que garantiza normalidad)
ggplot(data = data.frame(residuos = rstandard(regresion)), aes(sample = residuos)) +
  stat_qq(color = "dodgerblue") +
  stat_qq_line(color = "red", linetype = "dashed") +
  theme_minimal() +
  labs(title = "Q-Q Plot de residuos estandarizados",
       x = "Cuantiles teóricos",
       y = "Cuantiles muestrales")
# Out:
# plot without title

# %% [markdown]
# ## Calidad del ajuste

# %% [markdown]
# * Descomposición de la suma de cuadrados

# %% [markdown]
# ![descomposicion.png](attachment:37faf0c0-476b-490e-a3b7-360eeff7d753.png)

# %% [markdown]
# * Yi − ¯Y = Yi − ^Yi + ^Yi − ¯Y
# * Desviación total:                                   Yi − ¯Y
# * Desvío de los predichos respecto de la media:      ^Yi − ¯Y
# * Desvío alrededor de la recta de regresión ajustada: Yi − ^Yi

# %% [markdown]
# * **Coeficiente de determinación R^2**: indica qué parte de la variabilidad total de la variable dependiente Y es explicada por la variable independiente. Por lo tanto, sirve como una medida del poder predictivo del modelo

# %%
summary(regresion)
# Out:
# Call:
# lm(formula = grasas ~ edad, data = grasas)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -63.478 -26.816  -3.854  28.315  90.881
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 102.5751    29.6376   3.461  0.00212 **
# edad          5.3207     0.7243   7.346 1.79e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 43.46 on 23 degrees of freedom
# Multiple R-squared:  0.7012,	Adjusted R-squared:  0.6882
# F-statistic: 53.96 on 1 and 23 DF,  p-value: 1.794e-07

# %% [markdown]
# * Multiple R-squared:  0.7012  **es R^2**
# * El valor 0.7012 implica una relación lineal moderadamente fuerte entre la edad de la persona y la cantidad de grasas en sangre
# * Este valor indica que el modelo explica un 70.12 % de la variabilidad observada
# * Por lo tanto, un 29.88 % de la variabilidad observada no queda explicada por el modelo

# %% [markdown]
# ## Inferencia para los parámetros del modelo

# %%
# Intervalos de confianza para los parámetros
confint(regresion) # nivel de confianza por default es 0.95
# Out:
#             2.5 %     97.5 %
# (Intercept) 41.265155 163.885130
# edad         3.822367   6.818986

# %%
# Cambiando el nivel de confianza
confint(regresion, level = 0.90)
# Out:
#             5 %       95 %
# (Intercept) 51.780153 153.370132
# edad         4.079335   6.562018

# %%
# Intervalo de confianza para 𝜎^2
# El estimador de la desviación típica de los errores, 𝜎, figura como Residual standard error 
# y su valor en el ejemplo es 43.5. Este valor se puede obtener con la instrucción sigma(regresion)
alfa <- 0.05
n <- dim(grasas)[1]
LSsigma <- (n-2) * sigma(regresion)^2 / qchisq(1-alfa / 2, n-2)
LIsigma <- (n-2) * sigma(regresion)^2 / qchisq(alfa / 2, n-2)
LSsigma
LIsigma
# Out:
# [1] 1141.002
# [1] 3716.831

# %% [markdown]
# ### Cálculo de predicciones

# %%
# predicción para estimar la cantidad de grasas en sangre de individuos cuyas edades van de 30 a 45 años
nuevas_edades <- data.frame(edad = c(30,45))
nuevas_edades

predict(regresion, nuevas_edades)
# Out:
#   edad
# 1 30
# 2 45
#        1        2
# 262.1954 342.0056

# %% [markdown]
# ### Intervalos de confianza y predicción

# %%
# Intervalo de confianza para predicciones individuales
predict(regresion, newdata=nuevas_edades, interval="prediction")
# Out:
#   fit      lwr      upr
# 1 262.1954 169.4957 354.8952
# 2 342.0056 249.8962 434.1150

# %%
# Intervalo de confianza para las predicciones de valores medios
predict(regresion, newdata=nuevas_edades, interval="confidence")
# Out:
#   fit      lwr      upr
# 1 262.1954 239.6112 284.7797
# 2 342.0056 321.9820 362.0292

# %% [markdown]
# **Observación**: Notar que la predicción del valor medio tiene un intervalo más estrecho que la predicción de valores individuales. Esto es lógico, pues el valor medio es siempre menos variable que los valores individuales

# %%
# Intervalo de confianza y predicción para un conjunto de nuevas observaciones
nuevas_edades <- data.frame(edad = seq(20, 60))

# %%
# Intervalo de confianza para la respuesta media
ic_con <- predict(regresion, nuevas_edades, interval = 'confidence')

# %%
# Intervalos de predicción
ic_pred <- predict(regresion, nuevas_edades, interval = 'prediction')

nuevas_edades_con_df <- cbind(nuevas_edades, ic_con)
nuevas_edades_pred_df <- cbind(nuevas_edades, ic_pred)
head(nuevas_edades_con_df)
head(nuevas_edades_pred_df)
# Out:
#   edad fit      lwr      upr
# 1 20   208.9887 175.1653 242.8120
# 2 21   214.3093 181.7453 246.8734
# 3 22   219.6300 188.3042 250.9558
# 4 23   224.9507 194.8395 255.0619
# 5 24   230.2714 201.3482 259.1946
# 6 25   235.5921 207.8268 263.3573
#   edad fit      lwr      upr
# 1 20   208.9887 112.9303 305.0470
# 2 21   214.3093 118.6871 309.9316
# 3 22   219.6300 124.4224 314.8377
# 4 23   224.9507 130.1357 319.7657
# 5 24   230.2714 135.8270 324.7158
# 6 25   235.5921 141.4958 329.6883

# %%
ggplot(grasas, aes(x=edad, y=grasas))+
  geom_point()+
  geom_smooth(method=lm, formula=y~x, se=TRUE, level=0.95, col='blue', fill='pink2') +
  geom_line(data = nuevas_edades_con_df,aes(x=edad,y=lwr), color="red", 
            linetype="dashed") +
  geom_line(data = nuevas_edades_con_df,aes(x=edad,y=upr),color="red",
            linetype="dashed")+     
  geom_line(data = nuevas_edades_pred_df,aes(x=edad,y=lwr),color="blue",
            linetype="dashed")+
  geom_line(data = nuevas_edades_pred_df,aes(x=edad,y=upr), color="blue",
            linetype="dashed") +
  theme_light()
# Out:
# plot without title
